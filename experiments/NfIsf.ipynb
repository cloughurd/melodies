# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, '../src/')
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.manifold import Isomap
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.base import clone
import matplotlib.pyplot as plt
from pathlib import Path
import pickle
from datetime import datetime

from preprocessing import BagOfNotes, MidiPathToDataFrame, PreprocessMidiDataFrame, NfIsf, BagOfChords2, Downsampler
import evaluation

# %%
data_dir = Path('../maestro/maestro-v3.0.0/')
# df = pd.read_csv(data_dir / 'maestro-v3.0.0.csv')
df = pd.read_csv('../eda/no_dups.csv', index_col=0)
keys = pd.read_csv('../eda/key_review.csv')
categories = pd.read_csv('../eda/categories.csv')
df = pd.merge(df, keys, how='left', on='canonical_title')
df = pd.merge(df, categories, how='left', on='canonical_title')
df.head()
# Out:
#    canonical_composer                canonical_title       split  year  \
# 0          Alban Berg                   Sonata Op. 1       train  2018
# 1  Alexander Scriabin  24 Preludes Op. 11, No. 13-24       train  2004
# 2  Alexander Scriabin               3 Etudes, Op. 65  validation  2006
# 3  Alexander Scriabin              5 Preludes, Op.15  validation  2009
# 4  Alexander Scriabin               Entragete, Op.63        test  2009
#
#                                        midi_filename  \
# 0  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...
# 1  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...
# 2  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...
# 3  2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MI...
# 4  2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MI...
#
#                                       audio_filename    duration draft_key  \
# 0  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...  698.661160       NaN
# 1  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...  872.640588       NaN
# 2  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...  397.857508       NaN
# 3  2009/MIDI-Unprocessed_07_R1_2009_04-05_ORIG_MI...  400.557826       NaN
# 4  2009/MIDI-Unprocessed_11_R1_2009_06-09_ORIG_MI...  163.745830       NaN
#
#   category
# 0   sonata
# 1  prelude
# 2    etude
# 3  prelude
# 4      NaN

# %%
df.describe(include='all')
# Out:
#        canonical_composer canonical_title  split         year  \
# count                 760             760    760   760.000000
# unique                 60             760      3          NaN
# top       Frédéric Chopin    Sonata Op. 1  train          NaN
# freq                   96               1    507          NaN
# mean                  NaN             NaN    NaN  2011.035526
# std                   NaN             NaN    NaN     4.316839
# min                   NaN             NaN    NaN  2004.000000
# 25%                   NaN             NaN    NaN  2008.000000
# 50%                   NaN             NaN    NaN  2011.000000
# 75%                   NaN             NaN    NaN  2015.000000
# max                   NaN             NaN    NaN  2018.000000
#
#                                             midi_filename  \
# count                                                 760
# unique                                                760
# top     2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            audio_filename     duration  \
# count                                                 760   760.000000
# unique                                                760          NaN
# top     2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...          NaN
# freq                                                    1          NaN
# mean                                                  NaN   547.348754
# std                                                   NaN   451.260671
# min                                                   NaN    45.155208
# 25%                                                   NaN   245.693679
# 50%                                                   NaN   377.910613
# 75%                                                   NaN   672.340407
# max                                                   NaN  2622.724407
#
#        draft_key category
# count        423      493
# unique        34        9
# top      c major   sonata
# freq          39      238
# mean         NaN      NaN
# std          NaN      NaN
# min          NaN      NaN
# 25%          NaN      NaN
# 50%          NaN      NaN
# 75%          NaN      NaN
# max          NaN      NaN

# %%
pd.crosstab(df.split, df.category.isna(), margins=True)
# Out:
# category    False  True  All
# split
# test          109    35  144
# train         322   185  507
# validation     62    47  109
# All           493   267  760

# %%
train = df[df.split == 'train']
validate = df[df.split == 'validation']

# %%
do_once = Pipeline([
    ('loader', MidiPathToDataFrame(data_dir)),
    ('cleaner', PreprocessMidiDataFrame()),
])
train_loaded = do_once.transform(train.midi_filename)
val_loaded = do_once.transform(validate.midi_filename)
# Out:
# C:\Users\benkc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# C:\Users\benkc\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\pipeline.py:62: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
vectorizers = [
    ('NfIsf', NfIsf(threshold=0)),
    ('NfIsf', NfIsf(threshold=0.001)),
    ('NfIsf', NfIsf(threshold=0.005)),
    ('NfIsf', NfIsf(threshold=0.01)),
]
reducers = [
    ('PCA2', PCA(2)),
]
clusterers = [
    ('kmeans', KMeans(n_clusters=20, n_init=10, random_state=6740*42)),
]
models = {}
results = {}
for v in vectorizers:
    for r in reducers:
        for c in clusterers:
            p = Pipeline([
                v,
                r,
                c,
            ])
            p = clone(p)
            p.fit(train_loaded)
            embeddings = p[:2].transform(val_loaded)
            clusters = p[2].predict(embeddings)
            scores = evaluation.evaluate_clusters(clusters, validate[['canonical_composer', 'draft_key', 'category']])
            name = f'{v[0]}-{r[0]}-{c[0]}'
            for s in scores:
                evaluation.plot_with_label(embeddings, validate[s], f'{name} (homogeneity={scores[s]:.4f})')
            models[name] = p
            results[name] = scores
